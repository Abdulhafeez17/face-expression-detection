# %%
# Install the ultralytics package from PyPI
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 133MB/s]

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
# !touch data.yaml

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 19.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.2 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=d2710aa37ec8466f2592a6c3bff60cdebb35175854c218c378161b1a6867e942
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
results = model.train(data='/content/drive/MyDrive/data.yaml', epochs=2500, imgsz=512, val=True, save=True, device=0, patience=0)
# Out:
# Ultralytics YOLOv8.0.204 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
inference=YOLO("/content/drive/MyDrive/runs/detect/train4/weights/best.pt")

# %%
inference.predict('/content/drive/MyDrive/test/images', save=True, imgsz=512, conf=0.5)
# Out:
# image 1/55 /content/drive/MyDrive/test/images/101.png: 512x512 (no detections), 27.9ms
# image 2/55 /content/drive/MyDrive/test/images/106.png: 512x512 (no detections), 25.7ms
# image 3/55 /content/drive/MyDrive/test/images/107.png: 512x512 (no detections), 26.0ms
# image 4/55 /content/drive/MyDrive/test/images/108.png: 512x512 (no detections), 25.5ms
# image 5/55 /content/drive/MyDrive/test/images/111.png: 512x512 1 plastic, 25.6ms
# image 6/55 /content/drive/MyDrive/test/images/115.png: 512x512 (no detections), 25.6ms
# image 7/55 /content/drive/MyDrive/test/images/118.jpg: 512x512 1 plastic, 25.6ms
# image 8/55 /content/drive/MyDrive/test/images/12.jpg: 512x512 (no detections), 25.6ms
# image 9/55 /content/drive/MyDrive/test/images/120.jpg: 512x512 3 wets, 25.5ms
# image 10/55 /content/drive/MyDrive/test/images/126.jpg: 512x512 3 wets, 25.6ms
# image 11/55 /content/drive/MyDrive/test/images/128.jpg: 512x512 3 wets, 25.6ms
# ...

# %%
inference = model('/content/drive/MyDrive/test/images/101.png')  # return a list of Results objects

# Process results list
for result in inference:
    boxes = result.boxes  # Boxes object for bbox outputs
    #masks = result.masks  # Masks object for segmentation masks outputs
    #keypoints = result.keypoints  # Keypoints object for pose outputs
    #probs = result.probs  # Probs object for classification outputs
# Out:
# image 1/1 /content/drive/MyDrive/test/images/101.png: 512x512 1 plastic, 27.8ms
# Speed: 2.3ms preprocess, 27.8ms inference, 8.8ms postprocess per image at shape (1, 3, 512, 512)

# %%
for r in inference:
    print(r.boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.3694], device='cuda:0')
# data: tensor([[1.4472e+00, 9.2081e+01, 3.4024e+02, 5.0779e+02, 3.6943e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (512, 512)
# shape: torch.Size([1, 6])
# xywh: tensor([[170.8427, 299.9370, 338.7910, 415.7124]], device='cuda:0')
# xywhn: tensor([[0.3337, 0.5858, 0.6617, 0.8119]], device='cuda:0')
# xyxy: tensor([[  1.4472,  92.0808, 340.2382, 507.7932]], device='cuda:0')
# xyxyn: tensor([[0.0028, 0.1798, 0.6645, 0.9918]], device='cuda:0')
